# %% [markdown]
# <a href="https://colab.research.google.com/github/Koushik-SCC/Laws/blob/main/planck's_law.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
lam = np.arange(1e-9,3e-6,1e-9)
c , k , h = 3*1e8 , 1.3807e-23 , 6.626e-34
def plank(lam,T):
  a = 8*np.pi*h*c
  b = h*c/(lam*k*T)
  energydensity = (a/lam**5)*(1/(np.exp(b)-1))
  return energydensity
plt.plot(lam*1e10,plank(lam,4000),'r-')
plt.plot(lam*1e10,plank(lam,5000),'g-')
plt.plot(lam*1e10,plank(lam,6000),'b-')
plt.plot(lam*1e10,plank(lam,7000),'k-')
plt.axvline(4000,color='brown',ls='--')
plt.axvline(7500,color='brown',ls='--')
plt.ylabel('Intensity')
plt.xlabel('wavelenght')
plt.text(10500,2.25e6,'Visible Range',color='red',size=16)
plt.arrow(10475,2.25e6,-2900,0.01,length_includes_head='True',head_width=1e2,width=50,color='green')
plt.arrow(10475,2.275e6,-6000,0.375e6,length_includes_head='True',head_width=1e2,width=50,color='green')
plt.title('Blackbody Radiation',size='18')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: overflow encountered in exp
